# %% [markdown]
# # 코드 실행

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from tqdm import tqdm_notebook as tq
import time

# %%
user_ID = "bumgiv@naver.comw"
user_PASSWORD = "the808bg486"

timeDelay_short = 2
timeDelay_medium = 3
timeDelay_long = 5

driver = wb.Chrome()
driver.get("https://elice.io/")
driver.maximize_window()
time.sleep(timeDelay_short)
driver.find_element(By.CLASS_NAME,"Button__StyledButton-sc-sgmtm1-0.kheXXG").click()
time.sleep(timeDelay_short)
driver.find_element(By.CLASS_NAME,"w2s5uu-0.blcwjU.eb-input").send_keys(user_ID)
time.sleep(timeDelay_short)
driver.find_elements(By.CLASS_NAME,"w2s5uu-0.blcwjU.eb-input")[1].send_keys(user_PASSWORD)
time.sleep(timeDelay_short)
driver.find_element(By.CLASS_NAME,"eb-button.eb-button--role-primary.eb-button--size-default.eb-button--block").click()
time.sleep(timeDelay_short)
driver.find_element(By.CLASS_NAME,"Button__StyledButton-sc-sgmtm1-0.ilcWzw").click()
time.sleep(timeDelay_medium)
driver.switch_to.window(driver.window_handles[-1])
time.sleep(timeDelay_short)
driver.find_elements(By.CLASS_NAME,"eb-header--nav-item")[1].click()

# %% [markdown]
# # 완성용

# %%
# 현재 트랙화면
for i in range(0,4):
    
    track = driver.find_elements(By.CLASS_NAME,"sc-24768g-4.emtygC")
    track[i].click()
    # 커리큘럼 화면
    time.sleep(timeDelay_medium)
    curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
    for i in range(1,len(curriculum)):  
        curriculum[i].click()
        # 수업목록 -시작하기 버튼을 찾아 공부하기 시작
        time.sleep(timeDelay_medium)
        lessonList = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.fXWXxi.eb-button__inner")
        time.sleep(timeDelay_short)
        for i in range(3,len(lessonList)):
            lessonList[i].click()
            time.sleep(timeDelay_medium)
            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
            time.sleep(timeDelay_short)
            while nextBtn.text=='다음':
                #강의가 있는지 여부
                lecture = len(driver.find_elements(By.CLASS_NAME,"sc-1a1otok-0.iooXzx.em-material-video-file"))
                time.sleep(timeDelay_short)
                if lecture==1:
                    time.sleep(timeDelay_long)
                    nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                    time.sleep(timeDelay_medium)
                    nextBtn.click()
                    time.sleep(timeDelay_medium)
                    if len(nextBtn)==2: 
                        time.sleep(timeDelay_short)
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                        time.sleep(timeDelay_medium)
                    else:
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[0]
                        time.sleep(timeDelay_medium)
                else:                    
                    nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                    time.sleep(timeDelay_short)
                    nextBtn.click()
                    time.sleep(timeDelay_medium)
                    nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")
                    time.sleep(timeDelay_short)
                    if len(nextBtn)==2:                        
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                        time.sleep(timeDelay_short)
                    else:
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[0]
                        time.sleep(timeDelay_short)
            # 왼쪽 최하단 방나가게 버튼            
            toListBtn = driver.find_element(By.CLASS_NAME,"eb-button.sc-1fcl7e0-0.djjuXy.eb-icon-button.eb-button--role-navy3.eb-button--size-tiny")
            time.sleep(timeDelay_short)
            toListBtn.click()
            time.sleep(timeDelay_medium)
            #왼쪽 학습공간 수업목록 보기
            driver.find_element(By.CLASS_NAME,"sc-17nu1f1-0.dOTWi.eb-side-nav-drawer__item").click()
            time.sleep(timeDelay_medium)
            lessonList = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.fXWXxi.eb-button__inner")
            time.sleep(timeDelay_short)
        #왼쪽 상단 (과목위_마크)
        driver.find_element(By.CLASS_NAME,"sc-101dz3v-0.cjigYt").click()
        time.sleep(timeDelay_medium)
        driver.find_element(By.CLASS_NAME,"eb-text.eb-text--role-primary.eb-text--size-small.eb-text--bold").click()
        time.sleep(timeDelay_medium)
        curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
        time.sleep(timeDelay_short)
    #최상단 내학습 탭
    driver.find_elements(By.CLASS_NAME,"eb-header--nav-item")[1].click()
    time.sleep(timeDelay_medium)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#      61 driver.find_element(By.CLASS_NAME,"sc-101dz3v-0.cjigYt").click()
#      62 time.sleep(timeDelay_medium)
# ---> 63 driver.find_element(By.CLASS_NAME,"eb-text.eb-text--role-primary.eb-text--size-small.eb-text--bold").click()
#      64 time.sleep(timeDelay_medium)
#      65 curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:88, in WebElement.click(self)
#      86 def click(self) -> None:
#      87     """Clicks the element."""
# ---> 88     self._execute(Command.CLICK_ELEMENT)
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:396, in WebElement._execute(self, command, params)
#     394     params = {}
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010D6463+2188387]
# 	Ordinal0 [0x0106E461+1762401]
# 	Ordinal0 [0x00F83D78+802168]
# 	Ordinal0 [0x00F77210+750096]
# 	Ordinal0 [0x00F7675A+747354]
# 	Ordinal0 [0x00F75D3F+744767]
# 	Ordinal0 [0x00F74C28+740392]
# 	Ordinal0 [0x00F75228+741928]
# 	Ordinal0 [0x00F7F153+782675]
# 	Ordinal0 [0x00F89FBB+827323]
# 	Ordinal0 [0x00F8D310+840464]
# 	Ordinal0 [0x00F754F6+742646]
# 	Ordinal0 [0x00F89BF3+826355]
# 	Ordinal0 [0x00FDCF6D+1167213]
# 	Ordinal0 [0x00FCC5F6+1099254]
# 	Ordinal0 [0x00FA6BE0+945120]
# 	Ordinal0 [0x00FA7AD6+948950]
# 	GetHandleVerifier [0x013771F2+2712546]
# 	GetHandleVerifier [0x0136886D+2652765]
# 	GetHandleVerifier [0x0116002A+520730]
# 	GetHandleVerifier [0x0115EE06+516086]
# 	Ordinal0 [0x0107468B+1787531]
# 	Ordinal0 [0x01078E88+1805960]
# 	Ordinal0 [0x01078F75+1806197]
# 	Ordinal0 [0x01081DF1+1842673]
# 	BaseThreadInitThunk [0x77527BA9+25]
# 	RtlInitializeExceptionChain [0x779EB7DB+107]
# 	RtlClearBits [0x779EB75F+191]

# %% [markdown]
# # 연습용

# %%
nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")
nextBtn

# %%
lecture = len(driver.find_elements(By.CLASS_NAME,"sc-1a1otok-0.iooXzx.em-material-video-file"))
lecture

# %%
# 현재 트랙화면
for i in range(2,4):
    track = driver.find_elements(By.CLASS_NAME,"sc-24768g-4.emtygC")
    time.sleep(timeDelay_short)
    track[i].click()
    # 커리큘럼 화면
    time.sleep(timeDelay_medium)
    curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
    for i in range(1,len(curriculum)):  
        curriculum[i].click()
        # 수업목록 -시작하기 버튼을 찾아 공부하기 시작
        time.sleep(timeDelay_medium)
        lessonList = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.fXWXxi.eb-button__inner")
        time.sleep(timeDelay_short)
        for i in range(3,len(lessonList)):
            lessonList[i].click()
            time.sleep(timeDelay_medium)
            try:
                nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                time.sleep(timeDelay_short)
                while nextBtn.text=='다음':
                    #강의가 있는지 여부
                    lecture = len(driver.find_elements(By.CLASS_NAME,"sc-1a1otok-0.iooXzx.em-material-video-file"))
                    time.sleep(timeDelay_short)
                    if lecture==1:
                        time.sleep(timeDelay_long)
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                        time.sleep(timeDelay_short)
                        nextBtn.click()
                        time.sleep(timeDelay_medium)
                        if len(nextBtn)==2:                        
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                            time.sleep(timeDelay_medium)
                        else:
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[0]
                            time.sleep(timeDelay_medium)
                    else:                    
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                        time.sleep(timeDelay_short)
                        nextBtn.click()
                        time.sleep(timeDelay_medium)
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")
                        time.sleep(timeDelay_short)
                        if len(nextBtn)==2:                        
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                            time.sleep(timeDelay_short)
                        else:
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[0]
                            time.sleep(timeDelay_short)
                # 왼쪽 최하단 방나가게 버튼            
                toListBtn = driver.find_element(By.CLASS_NAME,"eb-button.sc-1fcl7e0-0.djjuXy.eb-icon-button.eb-button--role-navy3.eb-button--size-tiny")
                time.sleep(timeDelay_short)
                toListBtn.click()
                time.sleep(timeDelay_medium)
                #왼쪽 학습공간 수업목록 보기
                driver.find_element(By.CLASS_NAME,"sc-17nu1f1-0.dOTWi.eb-side-nav-drawer__item").click()
                time.sleep(timeDelay_medium)
                lessonList = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.fXWXxi.eb-button__inner")
                time.sleep(timeDelay_short)
            except:
                nextBtn = driver.find_element(By.CLASS_NAME,"eb-button__label")
                time.sleep(timeDelay_short)
                if nextBtn[0]=='다음':
                    nextBtn.click()
                else:
                    toListBtn = driver.find_element(By.CLASS_NAME,"eb-button.sc-1fcl7e0-0.djjuXy.eb-icon-button.eb-button--role-navy3.eb-button--size-tiny")
                    time.sleep(timeDelay_short)
                    toListBtn.click()
                    time.sleep(timeDelay_medium)
        #왼쪽 상단 (과목위_마크)
        driver.find_element(By.CLASS_NAME,"sc-101dz3v-0.cjigYt").click()
        time.sleep(timeDelay_medium)
        backToCur = driver.find_element(By.CLASS_NAME,"sc-16vg2yq-0.iWWqBo")
        time.sleep(timeDelay_medium)
        backToCur.click()
        time.sleep(timeDelay_medium)
        curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
        time.sleep(timeDelay_short)
    #최상단 내학습 탭
    driver.find_elements(By.CLASS_NAME,"eb-header--nav-item")[1].click()
    time.sleep(timeDelay_medium)

# %%
driver.find_element(By.CLASS_NAME,"sc-16vg2yq-0.iWWqBo").click()

# %%
# 현재 트랙화면
for i in range(2,4):
    track = driver.find_elements(By.CLASS_NAME,"sc-24768g-4.emtygC")
    track[i].click()
    # 커리큘럼 화면
    time.sleep(timeDelay_medium)
    curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
    time.sleep(timeDelay_short)
    for i in range(1,len(curriculum)):  
        curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
        curriculum[i].click()
        time.sleep(timeDelay_medium)
        try: 
            # 수업목록 -시작하기 버튼을 찾아 공부하기 시작
            lessonList = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.fXWXxi.eb-button__inner")
            time.sleep(timeDelay_short)
            for i in range(3,len(lessonList)):
                lessonList[i].click()
                time.sleep(timeDelay_medium)
                nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                time.sleep(timeDelay_short)
                while nextBtn.text=='다음':
                    #강의가 있는지 여부
                    lecture = len(driver.find_elements(By.CLASS_NAME,"sc-1a1otok-0.iooXzx.em-material-video-file"))
                    time.sleep(timeDelay_short)
                    if lecture==1:
                        time.sleep(timeDelay_long)
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                        time.sleep(timeDelay_medium)
                        nextBtn.click()
                        time.sleep(timeDelay_medium)
                        if len(nextBtn)==2:                        
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                            time.sleep(timeDelay_medium)
                        else:
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[0]
                            time.sleep(timeDelay_medium)
                    else:                    
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                        time.sleep(timeDelay_short)
                        nextBtn.click()
                        time.sleep(timeDelay_medium)
                        nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")
                        time.sleep(timeDelay_short)
                        if len(nextBtn)==2:                        
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[1]
                            time.sleep(timeDelay_short)
                        else:
                            nextBtn = driver.find_elements(By.CLASS_NAME,"eb-button__label")[0]
                            time.sleep(timeDelay_short)    
                toListBtn = driver.find_element(By.CLASS_NAME,"eb-button.sc-1fcl7e0-0.djjuXy.eb-icon-button.eb-button--role-navy3.eb-button--size-tiny")
                time.sleep(timeDelay_short)
                toListBtn.click()
                time.sleep(timeDelay_medium)
                #왼쪽 학습공간 수업목록 보기
                driver.find_element(By.CLASS_NAME,"sc-17nu1f1-0.dOTWi.eb-side-nav-drawer__item").click()
                time.sleep(timeDelay_medium)
                lessonList = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.fXWXxi.eb-button__inner")
                time.sleep(timeDelay_short)
            #왼쪽 상단 (과목위_마크)
            driver.find_element(By.CLASS_NAME,"sc-101dz3v-0.cjigYt").click()
            time.sleep(timeDelay_medium)
            driver.find_element(By.CLASS_NAME,"eb-text.eb-text--role-primary.eb-text--size-small.eb-text--bold").click()
            curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
            time.sleep(timeDelay_short)
        except:
            driver.back()
            time.sleep(timeDelay_short)
            curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
            time.sleep(timeDelay_short)
            
    #최상단 내학습 탭
    driver.find_elements(By.CLASS_NAME,"eb-header--nav-item")[1].click()
    time.sleep(timeDelay_medium)

# %%
curriculum = driver.find_elements(By.CLASS_NAME,"sc-16vg2yq-0.bbMWWg")
curriculum
